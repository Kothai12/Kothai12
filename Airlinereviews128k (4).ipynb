# %%
#import packages


# !pip install numpy

# %%
# !pip install seaborn
# !pip install pandas

# %%
# !pip install matplotlib
# %matplotlib inline

# %%
# !pip install seaborn

# %%
# !pip install matplotlib

# %%
#defining packages

import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/admin/Downloads/archive (4)/AirlineReviews.csv',encoding = 'unicode escape')

# %%
df.shape
# Out:
# (129455, 22)

# %%
df.head(10)
# Out:
#         Aircraft    AirlineName      CabinType      DateFlown  \
# 0            NaN    AB Aviation  Economy Class  November 2019
# 1           E120    AB Aviation  Economy Class      June 2019
# 2  Embraer E120     AB Aviation  Economy Class      June 2019
# 3            NaN  Aerocaribbean  Economy Class            NaN
# 4            NaN  Aerocaribbean            NaN            NaN
# 5            NaN  Aerocaribbean            NaN            NaN
# 6            NaN     AeroItalia  Economy Class     April 2023
# 7        Dornier       Aero VIP  Economy Class     April 2019
# 8        Dornier       Aero VIP  Economy Class     April 2019
# 9  BAe Jetstream       Aero VIP  Economy Class      July 2017
#
#               DatePub  EntertainmentRating  FoodRating  GroundServiceRating  \
# 0  11th November 2019                    0           4                    4
# 1      25th June 2019                    0           1                    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129455 entries, 0 to 129454
# Data columns (total 22 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Aircraft             36423 non-null   object
#  1   AirlineName          129455 non-null  object
#  2   CabinType            126437 non-null  object
#  3   DateFlown            90993 non-null   object
#  4   DatePub              129455 non-null  object
#  5   EntertainmentRating  129455 non-null  int64
#  6   FoodRating           129455 non-null  int64
#  7   GroundServiceRating  129455 non-null  int64
#  8   OriginCountry        127777 non-null  object
#  9   OverallScore         125124 non-null  float64
#  10  Recommended          129455 non-null  object
#  11  Review               128631 non-null  object
#  12  Route                90825 non-null   object
#  13  SeatComfortRating    129455 non-null  int64
#  14  ServiceRating        129455 non-null  int64
# ...

# %%
#dropping unnecessary columns

df.drop(columns = ['unique_id'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129455 entries, 0 to 129454
# Data columns (total 21 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Aircraft             36423 non-null   object
#  1   AirlineName          129455 non-null  object
#  2   CabinType            126437 non-null  object
#  3   DateFlown            90993 non-null   object
#  4   DatePub              129455 non-null  object
#  5   EntertainmentRating  129455 non-null  int64
#  6   FoodRating           129455 non-null  int64
#  7   GroundServiceRating  129455 non-null  int64
#  8   OriginCountry        127777 non-null  object
#  9   OverallScore         125124 non-null  float64
#  10  Recommended          129455 non-null  object
#  11  Review               128631 non-null  object
#  12  Route                90825 non-null   object
#  13  SeatComfortRating    129455 non-null  int64
#  14  ServiceRating        129455 non-null  int64
# ...

# %%
#head function to eastablish 
df.head()
# Out:
#         Aircraft    AirlineName      CabinType      DateFlown  \
# 0            NaN    AB Aviation  Economy Class  November 2019
# 1           E120    AB Aviation  Economy Class      June 2019
# 2  Embraer E120     AB Aviation  Economy Class      June 2019
# 3            NaN  Aerocaribbean  Economy Class            NaN
# 4            NaN  Aerocaribbean            NaN            NaN
#
#               DatePub  EntertainmentRating  FoodRating  GroundServiceRating  \
# 0  11th November 2019                    0           4                    4
# 1      25th June 2019                    0           1                    1
# 2      25th June 2019                    0           1                    1
# 3  31st December 2010                    0           0                    0
# 4  25th November 2010                    0           0                    0
#
#    OriginCountry  OverallScore  ...  \
# 0    Netherlands           9.0  ...
# 1  UnitedKingdom           1.0  ...
# ...

# %%
#REMOVING NULL VALUES

pd.isnull(df)
# Out:
#         Aircraft  AirlineName  CabinType  DateFlown  DatePub  \
# 0           True        False      False      False    False
# 1          False        False      False      False    False
# 2          False        False      False      False    False
# 3           True        False      False       True    False
# 4           True        False       True       True    False
# ...          ...          ...        ...        ...      ...
# 129450      True        False      False       True    False
# 129451      True        False      False       True    False
# 129452      True        False      False       True    False
# 129453      True        False      False       True    False
# 129454      True        False      False       True    False
#
#         EntertainmentRating  FoodRating  GroundServiceRating  OriginCountry  \
# 0                     False       False                False          False
# 1                     False       False                False          False
# ...

# %%
pd.isnull(df).sum()
# Out:
# Aircraft               93032
# AirlineName                0
# CabinType               3018
# DateFlown              38462
# DatePub                    0
# EntertainmentRating        0
# FoodRating                 0
# GroundServiceRating        0
# OriginCountry           1678
# OverallScore            4331
# Recommended                0
# Review                   824
# Route                  38630
# SeatComfortRating          0
# ServiceRating              0
# Slug                       0
# Title                      4
# TravelType             38309
# TripVerified           69947
# ValueRating                0
# WifiRating                 0
# dtype: int64

# %%
#TABLE shows true and false whetre true indicates null.we need to remove nulls inplace of true.
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (18619, 21)

# %%
df.columns
# Out:
# Index(['Aircraft', 'AirlineName', 'CabinType', 'DateFlown', 'DatePub',
#        'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
#        'OriginCountry', 'OverallScore', 'Recommended', 'Review', 'Route',
#        'SeatComfortRating', 'ServiceRating', 'Slug', 'Title', 'TravelType',
#        'TripVerified', 'ValueRating', 'WifiRating'],
#       dtype='object')

# %% [markdown]
# df.rename(columns={'Recommended':'SUGGESTED'})

# %% [raw]
# RENAMING THE RECOMMENDED TO SUGGESTED

# %%
df.rename(columns = {'Review' : 'SUGGESTED'})
# Out:
#              Aircraft    AirlineName      CabinType       DateFlown  \
# 1                E120    AB Aviation  Economy Class       June 2019
# 2       Embraer E120     AB Aviation  Economy Class       June 2019
# 7             Dornier       Aero VIP  Economy Class      April 2019
# 8             Dornier       Aero VIP  Economy Class      April 2019
# 12             CR 900  Adria Airways  Economy Class  September 2019
# ...               ...            ...            ...             ...
# 128932           A321       Wizz Air  Economy Class    January 2018
# 128935           A320       Wizz Air  Economy Class     August 2017
# 128942       A321-200       Wizz Air  Economy Class    October 2017
# 128944         Airbus       Wizz Air  Economy Class   December 2017
# 128946           A320       Wizz Air  Economy Class   November 2017
#
#                     DatePub  EntertainmentRating  FoodRating  \
# 1            25th June 2019                    0           1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18619 entries, 1 to 128946
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Aircraft             18619 non-null  object
#  1   AirlineName          18619 non-null  object
#  2   CabinType            18619 non-null  object
#  3   DateFlown            18619 non-null  object
#  4   DatePub              18619 non-null  object
#  5   EntertainmentRating  18619 non-null  int64
#  6   FoodRating           18619 non-null  int64
#  7   GroundServiceRating  18619 non-null  int64
#  8   OriginCountry        18619 non-null  object
#  9   OverallScore         18619 non-null  float64
#  10  Recommended          18619 non-null  object
#  11  Review               18619 non-null  object
#  12  Route                18619 non-null  object
#  13  SeatComfortRating    18619 non-null  int64
#  14  ServiceRating        18619 non-null  int64
# ...

# %%
#change datatypes

df['OverallScore'] = df['OverallScore'].astype('int')

# %%
df['OverallScore'].dtypes
# Out:
# dtype('int32')

# %%
df.describe()
# Out:
#        EntertainmentRating    FoodRating  GroundServiceRating  OverallScore  \
# count         18619.000000  18619.000000         18619.000000  18619.000000
# mean              1.935013      2.543101             3.066760      5.501692
# std               1.879970      1.778625             1.601542      3.411927
# min               0.000000      0.000000             0.000000      1.000000
# 25%               0.000000      1.000000             1.000000      2.000000
# 50%               1.000000      3.000000             3.000000      6.000000
# 75%               4.000000      4.000000             5.000000      9.000000
# max               5.000000      5.000000             5.000000     10.000000
#
#        SeatComfortRating  ServiceRating   ValueRating    WifiRating
# count       18619.000000   18619.000000  18619.000000  18619.000000
# mean            3.111016       3.398947      3.149954      0.863365
# std             1.471021       1.576199      1.577982      1.517407
# ...

# %%
df.drop(columns=['Recommended'],inplace =True)

# %%
df.columns
# Out:
# Index(['Aircraft', 'AirlineName', 'CabinType', 'DateFlown', 'DatePub',
#        'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
#        'OriginCountry', 'OverallScore', 'Review', 'Route', 'SeatComfortRating',
#        'ServiceRating', 'Slug', 'Title', 'TravelType', 'TripVerified',
#        'ValueRating', 'WifiRating'],
#       dtype='object')

# %%
#dropping columns if necessary

# %%
df.drop(columns=['DatePub'],inplace = True)

# %%
df.columns
# Out:
# Index(['Aircraft', 'AirlineName', 'CabinType', 'DateFlown',
#        'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
#        'OriginCountry', 'OverallScore', 'Review', 'Route', 'SeatComfortRating',
#        'ServiceRating', 'Slug', 'Title', 'TravelType', 'TripVerified',
#        'ValueRating', 'WifiRating'],
#       dtype='object')

# %%
#specifying the 5.,which shortlisted only 5 rows
df.head(5)
# Out:
#          Aircraft    AirlineName      CabinType       DateFlown  \
# 1            E120    AB Aviation  Economy Class       June 2019
# 2   Embraer E120     AB Aviation  Economy Class       June 2019
# 7         Dornier       Aero VIP  Economy Class      April 2019
# 8         Dornier       Aero VIP  Economy Class      April 2019
# 12         CR 900  Adria Airways  Economy Class  September 2019
#
#     EntertainmentRating  FoodRating  GroundServiceRating  OriginCountry  \
# 1                     0           1                    1  UnitedKingdom
# 2                     0           1                    1  UnitedKingdom
# 7                     0           0                    5       Portugal
# 8                     0           0                    5       Portugal
# 12                    1           1                    1        Austria
#
#     OverallScore                                             Review  \
# 1              1  Moroni to Anjouan. It is a very small airline....
# ...

# %%
#separating month and year and forming a new column with it
import pandas as pd
df['year'] = pd.DatetimeIndex(df['DateFlown']).year
df['month'] = pd.DatetimeIndex(df['DateFlown']).month

# %%
df.columns
# Out:
# Index(['Aircraft', 'AirlineName', 'CabinType', 'DateFlown',
#        'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
#        'OriginCountry', 'OverallScore', 'Review', 'Route', 'SeatComfortRating',
#        'ServiceRating', 'Slug', 'Title', 'TravelType', 'TripVerified',
#        'ValueRating', 'WifiRating', 'year', 'month'],
#       dtype='object')

# %%
df.head(3)
# Out:
#         Aircraft  AirlineName      CabinType   DateFlown  EntertainmentRating  \
# 1           E120  AB Aviation  Economy Class   June 2019                    0
# 2  Embraer E120   AB Aviation  Economy Class   June 2019                    0
# 7        Dornier     Aero VIP  Economy Class  April 2019                    0
#
#    FoodRating  GroundServiceRating  OriginCountry  OverallScore  \
# 1           1                    1  UnitedKingdom             1
# 2           1                    1  UnitedKingdom             1
# 7           0                    5       Portugal             9
#
#                                               Review  ... SeatComfortRating  \
# 1  Moroni to Anjouan. It is a very small airline....  ...                 2
# 2  Anjouan to Dzaoudzi. A very small airline and ...  ...                 2
# 7  Cascais to Bragan̤a with Aero VIP. Services a...  ...                 4
#
#    ServiceRating         Slug                         Title    TravelType  \
# ...

# %%
df.head()
# Out:
#          Aircraft    AirlineName      CabinType       DateFlown  \
# 1            E120    AB Aviation  Economy Class       June 2019
# 2   Embraer E120     AB Aviation  Economy Class       June 2019
# 7         Dornier       Aero VIP  Economy Class      April 2019
# 8         Dornier       Aero VIP  Economy Class      April 2019
# 12         CR 900  Adria Airways  Economy Class  September 2019
#
#     EntertainmentRating  FoodRating  GroundServiceRating  OriginCountry  \
# 1                     0           1                    1  UnitedKingdom
# 2                     0           1                    1  UnitedKingdom
# 7                     0           0                    5       Portugal
# 8                     0           0                    5       Portugal
# 12                    1           1                    1        Austria
#
#     OverallScore                                             Review  ...  \
# ...

# %%
pd.isnull(df)
# Out:
#         Aircraft  AirlineName  CabinType  DateFlown  EntertainmentRating  \
# 1          False        False      False      False                False
# 2          False        False      False      False                False
# 7          False        False      False      False                False
# 8          False        False      False      False                False
# 12         False        False      False      False                False
# ...          ...          ...        ...        ...                  ...
# 128932     False        False      False      False                False
# 128935     False        False      False      False                False
# 128942     False        False      False      False                False
# 128944     False        False      False      False                False
# 128946     False        False      False      False                False
#
#         FoodRating  GroundServiceRating  OriginCountry  OverallScore  Review  \
# ...

# %%
pd.isnull(df).sum()
# Out:
# Aircraft               0
# AirlineName            0
# CabinType              0
# DateFlown              0
# EntertainmentRating    0
# FoodRating             0
# GroundServiceRating    0
# OriginCountry          0
# OverallScore           0
# Review                 0
# Route                  0
# SeatComfortRating      0
# ServiceRating          0
# Slug                   0
# Title                  0
# TravelType             0
# TripVerified           0
# ValueRating            0
# WifiRating             0
# year                   0
# month                  0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head(2)
# Out:
#         Aircraft  AirlineName      CabinType  DateFlown  EntertainmentRating  \
# 1           E120  AB Aviation  Economy Class  June 2019                    0
# 2  Embraer E120   AB Aviation  Economy Class  June 2019                    0
#
#    FoodRating  GroundServiceRating  OriginCountry  OverallScore  \
# 1           1                    1  UnitedKingdom             1
# 2           1                    1  UnitedKingdom             1
#
#                                               Review  ... SeatComfortRating  \
# 1  Moroni to Anjouan. It is a very small airline....  ...                 2
# 2  Anjouan to Dzaoudzi. A very small airline and ...  ...                 2
#
#    ServiceRating         Slug                         Title    TravelType  \
# 1              2  ab-aviation            Not a good airline  Solo Leisure
# 2              1  ab-aviation  flight was fortunately short  Solo Leisure
#
#     TripVerified ValueRating  WifiRating  year  month
# ...

# %%
df = pd.read_csv('C:/Users/admin/Downloads/archive (4)/AirlineReviews.csv',encoding = 'unicode escape')

# %%
#finding unique values

df['AirlineName'].nunique()
# Out:
# 547

# %% [markdown]
# Airlinecounts=df['AirlineName'].value_counts()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,20))
import seaborn as sns
sns.countplot(y='AirlineName',data=df,order=Airlinecounts.index)

# %%
Airlines_top_25=Airlinecounts[:25].index

# %%
#above there is lot of airlinename which is not clear,im specifying top25 airlines below

# %%
plt.figure(figsize=(6,10))
sns.countplot(data=df,y='AirlineName',order=Airlines_top_25)
# Out:
# <Axes: xlabel='count', ylabel='AirlineName'>

# %%
df['OriginCountry'].nunique()
# Out:
# 202

# %%
df['Recommended'].nunique()
# Out:
# 2

# %%
print(df.isnull().sum())
# Out:
# Aircraft               93032
# AirlineName                0
# CabinType               3018
# DateFlown              38462
# DatePub                    0
# EntertainmentRating        0
# FoodRating                 0
# GroundServiceRating        0
# OriginCountry           1678
# OverallScore            4331
# Recommended                0
# Review                   824
# Route                  38630
# SeatComfortRating          0
# ServiceRating              0
# Slug                       0
# Title                      4
# TravelType             38309
# TripVerified           69947
# ValueRating                0
# WifiRating                 0
# unique_id                  0
# dtype: int64

# %%
sns.boxplot(df['FoodRating'])
# Out:
# <Axes: >

# %%
sns.barplot(x='ServiceRating',y='OverallScore',data=df)
# Out:
# <Axes: xlabel='ServiceRating', ylabel='OverallScore'>

# %%
sns.scatterplot(x='GroundServiceRating',y='WifiRating',data=df)
# Out:
# <Axes: xlabel='GroundServiceRating', ylabel='WifiRating'>

# %%
sns.histplot(x='SeatComfortRating',kde=True,data=df,color='m')
# Out:
# <Axes: xlabel='SeatComfortRating', ylabel='Count'>

# %%
correlationcols=['EntertainmentRating','FoodRating','GroundServiceRating','OverallScore','SeatComfortRating','ServiceRating','WifiRating','ValueRating']

# %%
corr_matrix=df[correlationcols].corr()

# %%
sns.heatmap(corr_matrix,cmap='Paired',annot=True)
plt.title("correlation of all ratings")
# Out:
# Text(0.5, 1.0, 'correlation of all ratings')

# %%
sns.lineplot(data=df,x='DateFlown',y='OverallScore',color='y')
# Out:
# <Axes: xlabel='DateFlown', ylabel='OverallScore'>

# %%
sns.countplot(x=df['Recommended'])
# Out:
# <Axes: xlabel='Recommended', ylabel='count'>

# %%
sns.countplot(x=df['TripVerified'])
# Out:
# <Axes: xlabel='TripVerified', ylabel='count'>

# %%
df.select_dtypes(exclude='O').hist(figsize=(8,5))
# Out:
# array([[<Axes: title={'center': 'EntertainmentRating'}>,
#         <Axes: title={'center': 'FoodRating'}>,
#         <Axes: title={'center': 'GroundServiceRating'}>],
#        [<Axes: title={'center': 'OverallScore'}>,
#         <Axes: title={'center': 'SeatComfortRating'}>,
#         <Axes: title={'center': 'ServiceRating'}>],
#        [<Axes: title={'center': 'ValueRating'}>,
#         <Axes: title={'center': 'WifiRating'}>, <Axes: >]], dtype=object)

# %%
import pandas as pd
df = pd.read_csv('C:/Users/admin/Downloads/archive (4)/AirlineReviews.csv',encoding = 'unicode escape')
import matplotlib as plt
df[df['OverallScore']==10.0]['AirlineName'].value_counts().nlargest(15).plot.bar(title='Airlines With The Best Overall Score',color='m')
# Out:
# <Axes: title={'center': 'Airlines With The Best Overall Score'}, xlabel='AirlineName'>

# %%
df[df['WifiRating']==5]['AirlineName'].value_counts().nlargest(15).plot.barh(title='Airlines With top WifiRating',color='c')
# Out:
# <Axes: title={'center': 'Airlines With top WifiRating'}, ylabel='AirlineName'>

# %%
sns.countplot(x='ValueRating',data=df)
# Out:
# <Axes: xlabel='ValueRating', ylabel='count'>

# %%
#CONCLUSION

I conclude overall score along with each rating airline in a specific manner and detailed representation
